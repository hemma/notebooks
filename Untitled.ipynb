# %%
jp_data <- read.csv2("jp_b_d.csv")
jp_death_ts <- ts(jp_data$Death, start=c(1966), end=c(2014), frequency=1)
jp_birth_ts <- ts(jp_data$Birth, start=c(1966), end=c(2014), frequency=1)
jp_pop_ts <- ts(jp_data$Pop, start=c(1966), end=c(2014), frequency=1)


ts.plot(jp_death_ts, jp_birth_ts, gpars= list(col = c("blue", "red")))
# Out:
# plot without title
